# %% [markdown]
# # 📊 Evaluate Captioning Models (Kaggle)
#
# Notebook này được cấu hình đặc biệt để chạy trên môi trường Kaggle.
# Thư viện `pycocoevalcap` (tính điểm SPICE, METEOR) bị lỗi trên các bản Java đời mới. Do đó chúng ta phải tải Java 11 và ép hệ thống hạ cấp lệnh `java` xuống bản 11.

# %%
import os

# 1. Cài đặt Java 11 (Bản cũ tương thích với thư viện SPICE)
# !apt-get update -qq
# !apt-get install -y openjdk-11-jdk-headless -qq > /dev/null

# 2. Ép hệ thống dùng lệnh java của bản 11 (Ghi đè bản Java mới mặc định của Kaggle)
# !update-alternatives --set java /usr/lib/jvm/java-11-openjdk-amd64/bin/java

# 3. Ép Python nhận diện đúng PATH và JAVA_HOME
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["PATH"] = f"{os.environ['JAVA_HOME']}/bin:{os.environ.get('PATH', '')}"

# Kiểm tra lại. Kết quả in ra bắt buộc phải là 'openjdk version "11.x.x"'
# !java -version

# %%
# Ép biến môi trường RUN_MODE thành v2 ngay trong Notebook
# os.environ["RUN_MODE"] = "v2_rag"

# Chạy script chấm điểm
# !python script/shared/evaluate.py
